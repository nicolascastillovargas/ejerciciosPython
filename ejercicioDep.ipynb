# %%
departamento = input ("escoge un departamento: A) quindio. B) cundinamarca. C) antioquia. D) valle. [A/B/C/D]? : ")

if departamento =="A":
    ciudad = input ("escoge una ciudad: A) armenia. B) montenegro. C) circasia. D) calarca. [A/B/C/D]? : ")

    #ciudad A quindio

    if ciudad == "A":
        
        opcion = input ("escoge una opcion: A) comidas. B) fauna. C) datos. D) musica. [A/B/C/D]? : ")
        if opcion =="A":
            comida = input("escoge una comida: A) sudado. B) mondongo. C) trucha. D) calentado. [A/B/C/D]? : ")
            if comida =="A":
                print("descripcion")
            elif comida =="B":
            print("descripcion")
                elif comida =="C":
                    print("descripcion")
                    elif comida =="D":
                    print("descripcion")
                        
        elif opcion =="B":
            fauna == input("escoge una animal: A)gupi . B)caraca . C)gavilan . D)torcaza . [A/B/C/D]? : ")
            if fauna =="A":
                print("descripcion")
            elif fauna =="B":
                print("descripcion")
            elif fauna =="C":
                print("descripcion")
            elif fauna =="D":
                print("descripcion")
               
        elif opcion =="C":
            datos == input("escoge un dato historico: A)fundacion . B)poblacion . C)altura . D)alcalde . [A/B/C/D]? : ")
            if datos =="A":
                print("descripcion")
            elif datos =="B":
                print("descripcion")
            elif datos =="C":
                print("descripcion")
            elif datos =="D":
                print("descripcion")
                 
        elif opcion =="D":
            musica == input("escoge una cancion: A)espumas . B)el barcino . C)la tierra del olvido . D)oropel . [A/B/C/D]? : ")
            if musica =="A":
                print("descripcion")
            elif musica =="B":
                print("descripcion")
            elif musica =="C":
                print("descripcion")
            elif musica =="D":
                print("descripcion")
       
    #ciudad B quindio
       
    elif ciudad == "B":
        opcion = input ("escoge una opcion: A) comidas . B) fauna . C) datos . D) musica [A/B/C/D]? : ")
        if opcion =="A":
            comida = input("escoge una comida: A) sudado. B) mondongo. C) trucha. D) calentado. [A/B/C/D]? : ")
            if comida =="A":
                print("descripcion")
            elif comida =="B":
                print("descripcion")
            elif comida =="C":
                print("descripcion")
            elif comida =="D":
                print("descripcion")
                
        elif opcion =="B":
            fauna == input("escoge una animal: A)gupi . B)caraca . C)gavilan . D)torcaza . [A/B/C/D]? : ")
            if fauna =="A":
                print("descripcion")
            elif fauna =="B":
                print("descripcion")
            elif fauna =="C":
                print("descripcion")
            elif fauna =="D":
                print("descripcion")
                
        elif opcion =="C":
            datos == input("escoge un dato historico: A)fundacion . B)poblacion . C)altura . D)alcalde . [A/B/C/D]? : ")
            if datos =="A":
                print("descripcion")
            elif datos =="B":
                print("descripcion")
            elif datos =="C":
                print("descripcion")
            elif datos =="D":
                print("descripcion")
                
        elif opcion =="D":
            musica == input("escoge una cancion: A)malitlde lina . B)la hamaca grande . C)acibar en los labios . D)el canalete . [A/B/C/D]? : ")
            if musica =="A":
                print("descripcion")
            elif musica =="B":
                print("descripcion")
            elif musica =="C":
                print("descripcion")
            elif musica =="D":
                print("descripcion")
            
        #ciudad C quindio
        
    elif ciudad == "C":
        opcion = input ("escoge una opcion: A) comidas . B) fauna . C) datos . D) musica [A/B/C/D]? : ")
        if opcion =="A":
            comida = input("escoge una comida: A) sudado. B) mondongo. C) trucha. D) calentado. [A/B/C/D]? : ")
            if comida =="A":
                print("descripcion")
            elif comida =="B":
                print("descripcion")
            elif comida =="C":
                print("descripcion")
            elif comida =="D":
                print("descripcion")
                           
        elif opcion =="B":
            fauna == input("escoge una animal: A)gupi . B)caraca . C)gavilan . D)torcaza . [A/B/C/D]? : ")
            if fauna =="A":
                print("descripcion")
            elif fauna =="B":
                print("descripcion")
            elif fauna =="C":
                print("descripcion")
            elif fauna =="D":
                print("descripcion")
                           
        elif opcion =="C":
            datos == input("escoge un dato historico: A)fundacion . B)poblacion . C)altura . D)alcalde . [A/B/C/D]? : ")
            if datos =="A":
                print("descripcion")
            elif datos =="B":
                print("descripcion")
            elif datos =="C":
                print("descripcion")
            elif datos =="D":
                print("descripcion")
                           
        elif opcion =="D":
            musica == input("escoge una cancion: A)llamarada . B)los remansos . C)la ruana . D)muchacha de risa loca . [A/B/C/D]? : ")
            if musica =="A":
                print("descripcion")
            elif musica =="B":
                print("descripcion")
            elif musica =="C":
                print("descripcion")
            elif musica =="D":
                print("descripcion")
                           
        #ciudad D quindio
                           
    elif ciudad == "D":
        opcion = input ("escoge una opcion: A) comidas . B) fauna . C) datos . D) musica [A/B/C/D]? : ")
        if opcion =="A":
            comida = input("escoge una comida: A) sudado. B) mondongo. C) trucha. D) calentado. [A/B/C/D]? : ")
            if comida =="A":
                print("descripcion")
            elif comida =="B":
                print("descripcion")
            elif comida =="C":
                print("descripcion")
            elif comida =="D":
                print("descripcion")
                           
        elif opcion =="B":
            fauna == input("escoge una animal: A)gupi . B)caraca . C)gavilan . D)torcaza . [A/B/C/D]? : ")
            if fauna =="A":
                print("descripcion")
            elif fauna =="B":
                print("descripcion")
            elif fauna =="C":
                print("descripcion")
            elif fauna =="D":
                print("descripcion")
                           
        elif opcion =="C":
            datos == input("escoge un dato historico: A)fundacion . B)poblacion . C)altura . D)alcalde . [A/B/C/D]? : ")
            if datos =="A":
                print("descripcion")
            elif datos =="B":
                print("descripcion")
            elif datos =="C":
                print("descripcion")
            elif datos =="D":
                print("descripcion")
                           
        elif opcion =="D":
            musica == input("escoge una cancion: A)pesares. B)las acacias . C)huri . D)la enredadera. [A/B/C/D]? : ")
            if musica =="A":
                print("descripcion")
            elif musica =="B":
                print("descripcion")
            elif musica =="C":
                print("descripcion")
            elif musica =="D":
                print("descripcion")
